# %% [markdown]
# # Vehicle Routing Problem with time windows constraints - Solved with MOCell

# %% [markdown]
# Sources :
#
# - Solving the Vehicle Routing Problem with Genetic Algorithm and Simulated Annealing : http://www.diva-portal.org/smash/get/diva2:518434/FULLTEXT01.pdf
# - Multi-objective Optimization of Vehicle Routing with Environmental Penalty : https://drive.google.com/file/d/1l9zI3--MH2tCF35unvGLem6fOUbOUx1O/view?usp=sharing

# %% [markdown]
# ## Problem definition
#
# The vehicle routing problem (VRP) is a superset of the traveling salesman problem (TSP). In a TSP, one set of stops is sequenced in an optimal fashion. **In a VRP, a set of orders needs to be assigned to a set of routes or vehicles such that the overall path cost is minimized.** It also needs to honor real-world constraints including vehicle capacities, delivery time windows, and driver specialties for example.
#
# The VRP produces a solution that honors these constraints while minimizing an objective function composed of operating costs and user preferences, such as the importance of meeting time windows.
#
# Specifically for this project, we decided to solve the VRP problem with time windows constraints. So the problem is the following:
# - Minimize the maximum distance of a route
# - Minimize the number of vehicles
# - Minimize the route balance, ie the difference of distance between the routes
# - Satisfy the constraints of delivering enough resources to satisfy each customer
# - Satisfy the time windows
#
# MOCell :
#
# ![image.png](attachment:c2bfcb1c-869a-4377-94de-e060e8d242ba.png)
#
# The VRP solver MOCell is a genetic algorithm similar to NSGA-II. The above schema describes the different steps of the solver.
#
# The main feature of this approach is that the population is distributed in a two-dimensional toroidal grid, to then assign a neighborhood to each individual. A toroidal mesh is used to ensure that all individuals have the same number of neighbors. MOCell performs this type of population distribution in order to restrict the number of individuals that can interact with each other, promoting the exploration of the search space so that genes are transmitted between neighborhoods without the need for focus only on the best individual of each subgroup, and maintaining a high diversity due to the “slow” diffusion of the genetic material. On the other hand, since individuals can only interact with a small group of neighbors, they seek to encourage exploitation in each neighborhood, using the ranking and distance stacking techniques proposed in NSGA-II in each neighborhood and thus promote elitism when applying genetic operators.
#
#
# We choosed to implement the MOCell solver regarding the recent litterature (2019, links are above) about the Vehicle Routing Problem. Indeed, as you can see in the figures below, the MOCell solver outperforms NSGA-II in the approximation of the Pareto front.
#
# ![Screenshot from 2021-04-11 11-45-39.png](attachment:666cd061-4718-42c5-bbb9-32c3b86a20f6.png)
#
# The hypervolume and the spread are better for the MOCell solver than NSGA-II. As defined in the paper, the hypervolume indicator calculates the volume covered by
# members of a non-dominated set of solutions of the Pareto front. The spread is a diversity indicator that measures the extent of spread achieved among the obtained solutions.
#
# ![Screenshot from 2021-04-11 11-45-48.png](attachment:267a704d-708b-4799-bd14-6df4ceddae75.png)

# %% [markdown]
# ## Problem modelisation
#
# ![171729093_2909537552655431_974676608512159985_n.png](attachment:2d4db2a0-5dca-4259-892c-21a4fe9f7e32.png)
#
# We defined the problem as below:
# - a list of customers placed over a map with coordinates (they contains their own constraints such as demand or due_date)
# - a number of vehicles that can bring resources to the customers
# - a capacity of resources for each vehicle
# - a list of depots and their location
#
#
# A solution is a list of routes for each vehicle. For example, a solution with 3 vehicles will be a list of 3 routes. Each route will link different customers (As you can see in the figure above).
#
# The lookout of solution is made only inside the set of feasible solutions (ie. solutions satisfying the constraints of capacity and time).

# %% [markdown]
# ## Benchmark
#
# We used the Solomon benchmark. Indeed this benchmark includes time windows constraint and demand of the customers. A file of this benchmark is defined as below:
#
# ![Screenshot from 2021-04-11 12-05-45.png](attachment:83f3d6b5-ef23-4b67-bd84-a71340babacf.png)

# %% [markdown]
# ## Problem solving

# %%
from VRPTW import *
import os

from jmetal.algorithm.multiobjective import MOCell
from jmetal.operator import PolynomialMutation, SBXCrossover
from jmetal.problem import ZDT1
from jmetal.util.termination_criterion import StoppingByEvaluations
from jmetal.util.neighborhood import C9
from jmetal.util.archive import CrowdingDistanceArchive

from jmetal.util.solution import get_non_dominated_solutions
from jmetal.lab.visualization import Plot

from ipynb.fs.defs.draw_solution import *

if not os.path.exists('solutions'):
    os.mkdir('solutions')

# %% [markdown]
# ## Constants

# %%
PROBLEM_FILE = "instances/C108.txt"

# %% [markdown]
# ## Create problem

# %%
assert os.path.exists(PROBLEM_FILE), "Problem file doesn't exist"
problem = SolomonFormatParser(PROBLEM_FILE).get_problem()
print(problem)
# Out:
# Instance: C108
# Vehicle number: 25
# Vehicle capacity: 200

# %% [markdown]
# ## Solve the problem using MOCell

# %%
algorithm = MOCell(problem=problem,
                  population_size=100,
                  neighborhood=C9(3, 3),
                  archive=CrowdingDistanceArchive(100),
                  mutation=PolynomialMutation(probability=1.0 / problem.number_of_variables, distribution_index=20),
                  crossover=SBXCrossover(probability=1.0, distribution_index=20),
                  termination_criterion=StoppingByEvaluations(max_evaluations=25000))

solution = algorithm.run()

with open(f"""solutions/{PROBLEM_FILE.split(os.sep)[-1].split(".")[0]}.sol""", 'w') as f:
    f.write(problem.print_canonical(solution))
# Out:
# 0 0.0 65 12.806248474865697 5 128.51616873923058 98 237.38413100334378 27 369.26491418608765 29 462.87046546155165 30 557.8704654615517 28 650.8704654615517 48 766.3655630295157 51 859.3655630295157 50 951.6016310070155 52 1044.7639086671838 0 1155.9771121027802
# 0 0.0 17 33.301651610693426 57 187.20783284537526 55 279.20783284537526 62 390.74849207391327 74 483.74849207391327 72 578.7484920739132 60 699.554335675412 68 816.4801597110845 66 911.865324518219 1 1034.925875027852 0 1143.6074167201214
# 0 0.0 87 25.495097567963924 20 150.8504366272913 43 256.14749516806967 40 351.5326599752042 10 477.5326599752042 11 570.5326599752042 85 694.7379227281783 88 787.7379227281783 89 880.5663498529245 21 1004.1073695154214 49 1111.2246122840452 0 1220.4339849963437
# ...

# %% [markdown]
# ## Draw the solution

# %%
draw_solution(PROBLEM_FILE, problem.print_canonical(solution).split('\n'))
